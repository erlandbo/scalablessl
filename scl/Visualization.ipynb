# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
test_embeds_labels = np.load("embeds/scl_test_embeds_.csv.npz")

# %%
embeds = test_embeds_labels["data"]
labels = test_embeds_labels["labels"]

# %%
embed_2d = embeds[:,0:2]
embed_2d.shape
# Out:
# (10000, 2)

# %%
z = zip(embed_2d[:,0], embed_2d[:, 1])

# %%
plt.figure(figsize=(25, 25))
plt.scatter(embed_2d[:,0], embed_2d[:, 1], c=labels)

# %%
fig, ax = plt.subplots(figsize=(25,25))
ax.scatter(embed_2d[:,0], embed_2d[:, 1], c=labels)
